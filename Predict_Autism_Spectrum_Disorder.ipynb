# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Analysis
#
# PIMA Diabetes Dataset

# %%
# loading the diabetes dataset to a pandas DataFrame
# Replace `from google.colab import files`
# Example local file loading
file_path = "C:\\Users\\Khan Mohd Arshad\\Downloads\\Major-Project-1\\ASD-predicting-ml-project\\asd_data_csv.csv"
data = pd.read_csv(file_path)

# %%
# Load the dataset
import pandas as pd

# Example of loading from a local file
file_path = r"C:\Users\Khan Mohd Arshad\Downloads\Major-Project-1\ASD-predicting-ml-project\asd_data_csv.csv"
data = pd.read_csv(file_path)

# Display the first 5 rows of the dataset
data.head()
# Out:
#    Social_Responsiveness_Scale  Age_Years  Speech Delay/Language Disorder  \
# 0                            3          2                               1
# 1                            6          3                               1
# 2                            7          3                               1
# 3                            1          2                               1
# 4                            3          2                               1
#
#    Learning disorder  Genetic_Disorders  Depression  \
# 0                  1                  1           1
# 1                  1                  1           1
# 2                  1                  1           1
# 3                  1                  0           1
# 4                  1                  0           1
#
#    Global developoental delay/intellectual disability  \
# 0                                                  1
# 1                                                  1
# ...

# %%
# Number of rows and columns in this dataset
data.shape
# Out:
# (1961, 13)

# %%
# Getting the statistical measures of the data
data.describe()
# Out:
#        Social_Responsiveness_Scale    Age_Years  \
# count                  1961.000000  1961.000000
# mean                      3.083631     9.618052
# std                       3.691156     4.301336
# min                       0.000000     1.000000
# 25%                       0.000000     7.000000
# 50%                       1.000000     9.000000
# 75%                       5.000000    14.000000
# max                      10.000000    18.000000
#
#        Speech Delay/Language Disorder  Learning disorder  Genetic_Disorders  \
# count                     1961.000000        1961.000000        1961.000000
# mean                         0.527282           0.535951           0.505354
# std                          0.499382           0.498833           0.500099
# min                          0.000000           0.000000           0.000000
# 25%                          0.000000           0.000000           0.000000
# ...

# %%
# Getting the value counts for the 'Outcome' column
data['Outcome'].value_counts()
# Out:
# 1    1056
# 0     905
# Name: Outcome, dtype: int64

# %% [markdown]
# 0 --> Not with ASD
#
# 1 --> With ASD

# %%
# Grouping the data by 'Outcome' and calculating the mean for each group
data.groupby('Outcome').mean()
# Out:
#          Social_Responsiveness_Scale  Age_Years  \
# Outcome
# 0                           1.942541   9.717127
# 1                           4.061553   9.533144
#
#          Speech Delay/Language Disorder  Learning disorder  Genetic_Disorders  \
# Outcome
# 0                              0.354696           0.367956           0.340331
# 1                              0.675189           0.679924           0.646780
#
#          Depression  Global developoental delay/intellectual disability  \
# Outcome
# 0          0.353591                                           0.352486
# 1          0.673295                                           0.674242
#
#          Social/Behavioural Issues  Anxiety_disorder       Sex  Jaundice  \
# Outcome
# 0                         0.353591          0.352486  0.469613  0.704972
# 1                         0.673295          0.671402  0.104167  0.828598
#
#          Family_member_with_ASD
# Outcome
# 0                      0.184530
# ...

# %%
import pandas as pd

# Load the autism dataset
autism_dataset = pd.read_csv('C:\\Users\\Khan Mohd Arshad\\Downloads\\Major-Project-1\\ASD-predicting-ml-project\\asd_data_csv.csv')


# Check if the dataset is loaded correctly
print(autism_dataset.head())

# Separating the features and labels
X = autism_dataset.drop(columns='Outcome', axis=1)  # Features
Y = autism_dataset['Outcome']  # Labels
# Out:
#    Social_Responsiveness_Scale  Age_Years  Speech Delay/Language Disorder  \
# 0                            3          2                               1
# 1                            6          3                               1
# 2                            7          3                               1
# 3                            1          2                               1
# 4                            3          2                               1
#
#    Learning disorder  Genetic_Disorders  Depression  \
# 0                  1                  1           1
# 1                  1                  1           1
# 2                  1                  1           1
# 3                  1                  0           1
# 4                  1                  0           1
#
#    Global developoental delay/intellectual disability  \
# 0                                                  1
# 1                                                  1
# ...

# %%
# loading the diabetes dataset to a pandas DataFrame
# Replace `from google.colab import files`
# Example local file loading
file_path = "C:\\Users\\Khan Mohd Arshad\\Downloads\\Major-Project-1\\ASD-predicting-ml-project\\asd_data_csv.csv"
data = pd.read_csv(file_path)

# %%
print(X)
# Out:
#       Social_Responsiveness_Scale  Age_Years  Speech Delay/Language Disorder  \
# 0                               3          2                               1
# 1                               6          3                               1
# 2                               7          3                               1
# 3                               1          2                               1
# 4                               3          2                               1
# ...                           ...        ...                             ...
# 1956                            1          7                               0
# 1957                            0         14                               0
# 1958                            1          7                               0
# 1959                            0         14                               0
# 1960                            1          7                               0
#
# ...

# %%
print(Y)
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1956    0
# 1957    0
# 1958    1
# 1959    0
# 1960    1
# Name: Outcome, Length: 1961, dtype: int64

# %% [markdown]
# Data Standardization

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(X)

# %%
print(standardized_data)
# Out:
# [[-0.02266285 -1.77154153  0.94684654 ...  1.63261158  0.54415114
#   -0.69766208]
#  [ 0.7902979  -1.53899632  0.94684654 ... -0.61251556  0.54415114
#   -0.69766208]
#  [ 1.06128481 -1.53899632  0.94684654 ... -0.61251556  0.54415114
#   -0.69766208]
#  ...
#  [-0.56463669 -0.60881547 -1.05613735 ... -0.61251556 -1.83772472
#   -0.69766208]
#  [-0.8356236   1.01900103 -1.05613735 ... -0.61251556 -1.83772472
#   -0.69766208]
#  [-0.56463669 -0.60881547 -1.05613735 ... -0.61251556 -1.83772472
#   -0.69766208]]

# %%
X = standardized_data
Y = autism_dataset['Outcome']

# %%
print(X)
print(Y)
# Out:
# [[-0.02266285 -1.77154153  0.94684654 ...  1.63261158  0.54415114
#   -0.69766208]
#  [ 0.7902979  -1.53899632  0.94684654 ... -0.61251556  0.54415114
#   -0.69766208]
#  [ 1.06128481 -1.53899632  0.94684654 ... -0.61251556  0.54415114
#   -0.69766208]
#  ...
#  [-0.56463669 -0.60881547 -1.05613735 ... -0.61251556 -1.83772472
#   -0.69766208]
#  [-0.8356236   1.01900103 -1.05613735 ... -0.61251556 -1.83772472
#   -0.69766208]
#  [-0.56463669 -0.60881547 -1.05613735 ... -0.61251556 -1.83772472
#   -0.69766208]]
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1956    0
# 1957    0
# 1958    1
# 1959    0
# 1960    1
# Name: Outcome, Length: 1961, dtype: int64

# %% [markdown]
# Train Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1961, 12) (1568, 12) (393, 12)

# %% [markdown]
# Training the Model

# %%
classifier = svm.SVC(kernel='linear')

# %%
#training the support vector Machine Classifier
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy score on the training data
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.6919642857142857

# %%
# accuracy score on the test data
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.7302798982188295

# %% [markdown]
# Making a Predictive System

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier  # Assuming you are using this classifier

# Assume scaler and classifier have already been trained and fitted to the training data
# scaler.fit(X_train)  # Example fitting of scaler on training data
# classifier.fit(X_train_scaled, Y_train)  # Example fitting of classifier on scaled training data

# Define the input data (ensure it has the same number of features as the training data)
# Adjust the number of features to match your training data (12 features in this case)
input_data = (0, 4, 0, 0, 0, 0, 0, 0, 1, 0, 1, 1)  # Must have 12 values

# Change input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# Reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)  # Shape should be (1, 12)

# Standardize the input data using the fitted scaler
# Make sure the number of features in the input_data_reshaped matches the scaler's expectations
try:
    std_data = scaler.transform(input_data_reshaped)
    print("Standardized input data:", std_data)

    # Make prediction using the classifier
    prediction = classifier.predict(std_data)
    print("Prediction:", prediction)

    # Interpret the prediction result
    if prediction[0] == 0:
        print('The person is not with Autism spectrum disorder')
    else:
        print('The person is with Autism spectrum disorder')

except ValueError as e:
    print("Error during transformation or prediction:", e)
# Out:
# Standardized input data: [[-0.8356236  -1.30645111 -1.05613735 -1.0746837  -1.01076678 -1.05290178
#   -1.05290178 -1.05290178  0.95267389 -0.61251556  0.54415114  1.43335869]]
# Prediction: [1]
# The person is with Autism spectrum disorder
# c:\Users\Khan Mohd Arshad\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
from sklearn.preprocessing import StandardScaler

# Assume X_train and X_test are your DataFrames containing the training and test data

# Initialize the scaler
scaler = StandardScaler()

# Fit and transform the training data directly using the DataFrame
X_train_scaled = scaler.fit_transform(X_train)  # No need to call .values
# Transform the test data using the fitted scaler
X_test_scaled = scaler.transform(X_test)  # No need to call .values

# Now X_train_scaled and X_test_scaled will be NumPy arrays
print("Scaled Training Data Shape:", X_train_scaled.shape)
print("Scaled Testing Data Shape:", X_test_scaled.shape)
# Out:
# Scaled Training Data Shape: (1568, 12)
# Scaled Testing Data Shape: (393, 12)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Sample training and testing data as DataFrames
X_train = pd.DataFrame({
    'feature1': [0, 1, 2],
    'feature2': [4, 5, 6],
    # Add other features as needed
})
X_test = pd.DataFrame({
    'feature1': [1, 0],
    'feature2': [3, 2],
    # Add corresponding features as needed
})

# Initialize the scaler
scaler = StandardScaler()

# Fit and transform the training data
X_train_scaled = scaler.fit_transform(X_train)  # No need to use .values

# Transform the test data
X_test_scaled = scaler.transform(X_test)  # No need to use .values

print("Scaled Training Data Shape:", X_train_scaled.shape)
print("Scaled Testing Data Shape:", X_test_scaled.shape)
# Out:
# Scaled Training Data Shape: (3, 2)
# Scaled Testing Data Shape: (2, 2)

# %%
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns)  # Assign feature names

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import sqlite3

# Connect to SQLite database or create it
conn = sqlite3.connect('autism_asd.db')

# Create a cursor object
cur=conn.cursor()

# %%
# Create table based on dataset structure (replace column names/types as necessary)
cur.execute('''
    CREATE TABLE IF NOT EXISTS ASD_Data (
        id INTEGER PRIMARY KEY,
        age INTEGER,
        gender TEXT,
        result TEXT,
        score REAL,
        target INTEGER
    )
''')

# Commit the changes
conn.commit()

# %%
import pandas as pd

# Load the CSV file (assuming you have it loaded in the environment)
df = pd.read_csv('C:\Users\Khan Mohd Arshad\Downloads\Major-Project-1\ASD-predicting-ml-project\data_csv.csv')

# Insert data into the database
df.to_sql('ASD_Data', conn, if_exists='replace', index=False)

# Commit and close the connection
conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[65], line 4
#       1 import pandas as pd
#       3 # Load the CSV file (assuming you have it loaded in the environment)
# ----> 4 df = pd.read_csv('ASD-predicting-ml-project\data_csv.csv')
#       6 # Insert data into the database
#       7 df.to_sql('ASD_Data', conn, if_exists='replace', index=False)
#
# File c:\Users\Khan Mohd Arshad\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\Khan Mohd Arshad\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...
